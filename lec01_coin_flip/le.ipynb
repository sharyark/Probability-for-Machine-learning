# %%
import random
import numpy as np
import matplotlib.pyplot as plt

# %%
# this is function willl give us flip
def coin_flip():
    return random.choice(['Heads', 'Tails'])

# %%
# Simulate 1000 coin flips
flips = [coin_flip() for _ in range(400)]

# %%
flips
# Out:
# ['Heads',
#  'Tails',
#  'Heads',
#  'Tails',
#  'Tails',
#  'Heads',
#  'Tails',
#  'Heads',
#  'Heads',
#  'Heads',
#  'Heads',
#  'Tails',
#  'Heads',
#  'Tails',
#  'Heads',
#  'Tails',
#  'Tails',
#  'Heads',
#  'Tails',
#  'Tails',
#  'Heads',
#  'Tails',
#  'Tails',
#  'Tails',
#  'Tails',
#  'Tails',
#  'Tails',
#  'Tails',
#  'Tails',
#  'Heads',
#  'Tails',
#  'Heads',
#  'Tails',
#  'Heads',
#  'Tails',
#  'Tails',
#  'Tails',
#  'Heads',
#  'Heads',
#  'Heads',
#  'Heads',
#  'Heads',
#  'Heads',
#  'Tails',
#  'Tails',
#  'Tails',
#  'Tails',
#  'Heads',
#  'Heads',
#  'Heads',
#  'Heads',
#  'Heads',
#  'Heads',
#  'Tails',
#  'Heads',
#  'Heads',
#  'Heads',
#  'Tails',
#  'Tails',
#  'Tails',
#  'Heads',
#  'Heads',
#  'Heads',
#  'Heads',
#  'Heads',
#  'Tails',
#  'Tails',
#  'Tails',
#  'Tails',
#  'Heads',
#  'Heads',
#  'Tails',
#  'Heads',
#  'Tails',
#  'Tails',
#  'Heads',
#  'Heads',
#  'Heads',
#  'Heads',
#  'Heads',
#  'Tails',
#  'Tails',
#  'Heads',
# ...

# %%
# Count the results
heads_count = flips.count('Heads')
tails_count = flips.count('Tails')

# %%
# Data for plotting
labels = ['Heads', 'Tails']
counts = [heads_count, tails_count]

# %%
counts
# Out:
# [215, 185]

# %%
# Create a bar graph
plt.bar(labels, counts, color=['blue', 'orange'])
plt.title('Coin Flip Results')
plt.xlabel('Outcome')
plt.ylabel('Count')
plt.ylim(0, max(counts) + 50)  # Adding some space above the tallest bar
plt.grid(axis='y')
# Display the results
plt.show()

# %% [markdown]
# so it is equally likly

# %%
# Now to monitor the cumulative results and probabilities
cumulative_heads = 0
cumulative_tails = 0
cumulative_prob_heads = []
cumulative_prob_tails = []

# %%
# Calculate cumulative counts and probabilities
for flip in flips:
    if flip == 'Heads':
        cumulative_heads += 1
    else:
        cumulative_tails += 1
    
    # Calculate probabilities
    total_flips = cumulative_heads + cumulative_tails
    cumulative_prob_heads.append(cumulative_heads / total_flips)
    cumulative_prob_tails.append(cumulative_tails / total_flips)

# %%
# Plotting cumulative probabilities
plt.figure(figsize=(10, 5))
plt.plot(cumulative_prob_heads, label='Probability of Heads', color='blue', linestyle='--')
plt.plot(cumulative_prob_tails, label='Probability of Tails', color='orange', linestyle='--')
plt.title('Cumulative Probability of Coin Flips')
plt.xlabel('Number of Flips')
plt.ylabel('Cumulative Probability')
plt.axhline(0.5, color='gray', linestyle=':', label='Expected Probability (0.5)')
plt.legend()
plt.ylim(0, 1)
plt.grid()
plt.show()
